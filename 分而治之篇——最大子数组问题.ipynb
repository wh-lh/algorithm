# %% [markdown]
# # 步骤

# %% [markdown]
# ![fc8669b52dd755e94928df428f46c89.jpg](attachment:fc8669b52dd755e94928df428f46c89.jpg)

# %% [markdown]
# ## 求解S3
# ![2df07561912f5c7a9719949aa57ec2f.jpg](attachment:2df07561912f5c7a9719949aa57ec2f.jpg)

# %% [markdown]
# ## 求解S3伪代码
# ![5e4f67fff721fbf9ee77d74cffd7db0.jpg](attachment:5e4f67fff721fbf9ee77d74cffd7db0.jpg)

# %% [markdown]
# ## 算法实例
# ![16bee8bf7346d003289e507acab818b.jpg](attachment:16bee8bf7346d003289e507acab818b.jpg)

# %% [markdown]
# ## 整体伪代码
# ![ce22ea23062d5c52717890f794f7de5.jpg](attachment:ce22ea23062d5c52717890f794f7de5.jpg)

# %% [markdown]
# # 解决此问题三种不同的算法以及他们各自的时间复杂度
# (1)蛮力枚举（O（n^3））
# (2)优化枚举（O（n^^2））
# (3)分而治之（O（nlogn））
